# %% [markdown]
# ## Configure the code
# - Import the libraries and configure the dictionary

# %%
import glob
import cv2 
from cv2 import aruco 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

arucoDict = cv2.aruco.Dictionary_get(aruco.DICT_4X4_250)

# %% [markdown]
# ## Create the Charuco board

# %%
board = aruco.CharucoBoard_create(10, 7, .03, .023, arucoDict)
myboard = board.draw((2000, 2000))

patternSize = (10,7)
squareSize = (.03)
#Show the board
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
plt.imshow(myboard, cmap = mpl.cm.gray, interpolation = "nearest")
ax.axis("off")
plt.show()

#Save the board
#cv2.imwrite("charuco.tiff", myboard)

# %% [markdown]
# ## After create the image, we need to take pictures of it
# - Make sure that you take a lot of images with differents angles
# - It's important that you have a light source behind your camera
# - The pattern must cover most of the image (at least a half)
#
# ### Now import the images to the code

# %%
images = glob.glob("*jpg")
print("Images uploaded")
# Out:
# Images uploaded

# %% [markdown]
# ## Fuction to detect the charuto corners

# %%
def detectCharucoCorners(images):
    allCorners = []
    allIds = []
    decimator = 0
    #subpixel corner detection criteria
    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.00001)
    
    for image in images:
        print("=> Processing image {0}".format(image))
        frame = cv2.imread(image)
        grayFrame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        corners, ids, rejectedImgPoints = cv2.aruco.detectMarkers(grayFrame, arucoDict)
        print(corners)
           
        
        
        # if the corners are valid 
        if len(corners)>0:
            print("Corners detected")
            for corner in corners:
                # do the subpixel detection
                cv2.cornerSubPix(grayFrame, corner, winSize = (3,3), zeroZone = (-1,-1), criteria = criteria)
            
            # returns the 2D position of the chessboard corners from a ChArUco board using the detected Aruco markers
            interpolatedCorners = cv2.aruco.interpolateCornersCharuco(corners, ids, grayFrame, board)
            print(interpolatedCorners[1])
            if interpolatedCorners[1] is not None and interpolatedCorners[2] is not None and len(interpolatedCorners[1]>3) and decimator%1==0:
                allCorners.append(interpolatedCorners[1])
                allIds.append(interpolatedCorners[2])
                worldPoints.append(boardPoints)
        decimator += 1
            
        
    imageSize = grayFrame.shape
    print("Corners are detected successfully!")
    
    return allCorners, allIds, imageSize

# %% [markdown]
# ## Function to calibrate the camera

# %%
def calibrateCameraUsingCharuco(allCorners, allIds, imageSize):
    print("STARTING CAMERA CALIBRATION")
    
    initialCameraMatrix = np.array([[ 1000.,    0., imageSize[0]/2.],
                                 [    0., 1000., imageSize[1]/2.],
                                 [    0.,    0.,           1.]])
    initialDistCoeffs = np.zeros((5,1))
    
    flags = (cv2.CALIB_USE_INTRINSIC_GUESS + cv2.CALIB_RATIONAL_MODEL + cv2.CALIB_FIX_ASPECT_RATIO)
    criteria = (cv2.TERM_CRITERIA_EPS & cv2.TERM_CRITERIA_COUNT, 10000, 1e-9)
    
    (ret, cameraMatrix, distortionCoefficients , rotationVectors, translationVectors, 
    stdDevIntrisics, stdDevExtrinsics, reprojectionError)  = cv2.aruco.calibrateCameraCharucoExtended(charucoCorners = allCorners,
                                                                                                      charucoIds = allIds,
                                                                                                      board = board,
                                                                                                      imageSize = imageSize,
                                                                                                      cameraMatrix = initialCameraMatrix,
                                                                                                      distCoeffs = initialDistCoeffs,
                                                                                                      flags = flags,
                                                                                                      criteria = criteria)
    print("CALIBRATION PROCESS DONE!")
    return ret, cameraMatrix, distortionCoefficients, rotationVectors, translationVectors, reprojectionError

# %% [markdown]
# ### Now, we can detect the markers and his corners
# - After this, the we'll have all we need to start the calibration

# %%
allCorners, allIds, imageSize = detectCharucoCorners(images)
# Out:
# => Processing image charucoImage1.jpg
# (array([[[1225., 1301.],
#         [1228., 1239.],
#         [1289., 1241.],
#         [1288., 1303.]]], dtype=float32), array([[[1061., 1297.],
#         [1062., 1236.],
#         [1125., 1237.],
#         [1124., 1298.]]], dtype=float32), array([[[ 803., 1127.],
#         [ 744., 1124.],
#         [ 749., 1065.],
#         [ 808., 1067.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage10.jpg
# (array([[[573., 646.],
#         [579., 591.],
#         [633., 592.],
#         [630., 645.]]], dtype=float32), array([[[350., 504.],
#         [298., 507.],
#         [303., 457.],
#         [355., 455.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage11.jpg
# (array([[[1118.,  693.],
#         [1121.,  632.],
#         [1185.,  635.],
#         [1183.,  697.]]], dtype=float32), array([[[ 950.,  690.],
#         [ 951.,  629.],
#         [1017.,  632.],
#         [1013.,  693.]]], dtype=float32), array([[[693., 525.],
#         [632., 525.],
#         [638., 467.],
#         [697., 467.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage12.jpg
# (array([[[1546.,  764.],
#         [1545.,  701.],
#         [1607.,  702.],
#         [1608.,  764.]]], dtype=float32), array([[[1380.,  762.],
#         [1380.,  700.],
#         [1443.,  702.],
#         [1442.,  763.]]], dtype=float32), array([[[1115.,  602.],
#         [1053.,  601.],
#         [1054.,  543.],
#         [1115.,  541.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage13.jpg
# (array([[[1959.,  748.],
#         [1956.,  690.],
#         [2015.,  690.],
#         [2018.,  748.]]], dtype=float32), array([[[1803.,  746.],
#         [1802.,  688.],
#         [1860.,  688.],
#         [1863.,  747.]]], dtype=float32), array([[[1545.,  593.],
#         [1487.,  594.],
#         [1485.,  537.],
#         [1545.,  537.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage14.jpg
# (array([[[2013.,  836.],
#         [2010.,  781.],
#         [2064.,  781.],
#         [2069.,  837.]]], dtype=float32), array([[[1864.,  835.],
#         [1862.,  780.],
#         [1918.,  779.],
#         [1921.,  835.]]], dtype=float32), array([[[1614.,  688.],
#         [1557.,  688.],
#         [1555.,  633.],
#         [1611.,  632.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage15.jpg
# (array([[[2019., 1144.],
#         [2019., 1093.],
#         [2069., 1096.],
#         [2068., 1147.]]], dtype=float32), array([[[1884., 1140.],
#         [1885., 1088.],
#         [1935., 1091.],
#         [1935., 1142.]]], dtype=float32), array([[[1663.,  995.],
#         [1611.,  992.],
#         [1613.,  942.],
#         [1664.,  945.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage16.jpg
# (array([[[1509., 1291.],
#         [1510., 1222.],
#         [1579., 1225.],
#         [1579., 1294.]]], dtype=float32), array([[[1324., 1283.],
#         [1327., 1214.],
#         [1397., 1218.],
#         [1395., 1287.]]], dtype=float32), array([[[1030., 1087.],
#         [ 961., 1083.],
#         [ 966., 1016.],
#         [1034., 1020.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage17.jpg
# (array([[[1194., 1177.],
#         [1197., 1108.],
#         [1267., 1113.],
#         [1265., 1180.]]], dtype=float32), array([[[1011., 1169.],
#         [1015., 1099.],
#         [1084., 1103.],
#         [1080., 1172.]]], dtype=float32), array([[[730., 975.],
#         [664., 971.],
#         [669., 906.],
#         [736., 910.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage18.jpg
# (array([[[1574.,  751.],
#         [1572.,  688.],
#         [1636.,  690.],
#         [1638.,  752.]]], dtype=float32), array([[[1404.,  748.],
#         [1402.,  684.],
#         [1467.,  686.],
#         [1468.,  748.]]], dtype=float32), array([[[1127.,  579.],
#         [1064.,  580.],
#         [1064.,  518.],
#         [1127.,  519.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage19.jpg
# (array([[[1421., 1680.],
#         [1421., 1617.],
#         [1484., 1619.],
#         [1483., 1681.]]], dtype=float32), array([[[1252., 1677.],
#         [1253., 1615.],
#         [1317., 1615.],
#         [1315., 1679.]]], dtype=float32), array([[[ 986., 1504.],
#         [ 923., 1503.],
#         [ 927., 1441.],
#         [ 988., 1445.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage2.jpg
# (array([[[ 899., 1511.],
#         [ 898., 1452.],
#         [ 958., 1453.],
#         [ 958., 1510.]]], dtype=float32), array([[[ 743., 1509.],
#         [ 741., 1449.],
#         [ 799., 1449.],
#         [ 801., 1508.]]], dtype=float32), array([[[ 493., 1344.],
#         [ 438., 1343.],
#         [ 439., 1287.],
#         [ 494., 1288.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage20.jpg
# (array([[[ 988., 1226.],
#         [ 944., 1266.],
#         [ 904., 1223.],
#         [ 948., 1182.]]], dtype=float32), array([[[1290., 1155.],
#         [1245., 1113.],
#         [1288., 1070.],
#         [1331., 1112.]]], dtype=float32), array([[[1404., 1042.],
#         [1360., 1001.],
#         [1401.,  959.],
#         [1444.,  999.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage3.jpg
# (array([[[1127., 1659.],
#         [1128., 1596.],
#         [1190., 1597.],
#         [1189., 1659.]]], dtype=float32), array([[[ 960., 1653.],
#         [ 963., 1590.],
#         [1025., 1593.],
#         [1023., 1654.]]], dtype=float32), array([[[ 701., 1479.],
#         [ 643., 1475.],
#         [ 646., 1416.],
#         [ 706., 1421.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage4.jpg
# (array([[[1686., 1605.],
#         [1685., 1545.],
#         [1742., 1546.],
#         [1742., 1604.]]], dtype=float32), array([[[1529., 1603.],
#         [1530., 1544.],
#         [1588., 1545.],
#         [1587., 1605.]]], dtype=float32), array([[[1273., 1446.],
#         [1215., 1445.],
#         [1217., 1385.],
#         [1274., 1386.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage5.jpg
# (array([[[2026., 1316.],
#         [2027., 1263.],
#         [2079., 1264.],
#         [2080., 1318.]]], dtype=float32), array([[[1883., 1315.],
#         [1883., 1260.],
#         [1937., 1260.],
#         [1938., 1316.]]], dtype=float32), array([[[1646., 1164.],
#         [1591., 1162.],
#         [1592., 1108.],
#         [1648., 1110.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage6.jpg
# (array([[[1982., 1620.],
#         [1983., 1568.],
#         [2033., 1567.],
#         [2033., 1619.]]], dtype=float32), array([[[2117., 1617.],
#         [2117., 1567.],
#         [2166., 1565.],
#         [2167., 1615.]]], dtype=float32), array([[[1760., 1486.],
#         [1709., 1486.],
#         [1710., 1435.],
#         [1761., 1436.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage7.jpg
# (array([[[2127., 1146.],
#         [2128., 1088.],
#         [2182., 1090.],
#         [2183., 1146.]]], dtype=float32), array([[[1978., 1143.],
#         [1978., 1085.],
#         [2035., 1087.],
#         [2034., 1144.]]], dtype=float32), array([[[1737.,  988.],
#         [1680.,  988.],
#         [1681.,  932.],
#         [1738.,  934.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage8.jpg
# (array([[[1655., 1212.],
#         [1653., 1149.],
#         [1717., 1149.],
#         [1718., 1212.]]], dtype=float32), array([[[1485., 1209.],
#         [1486., 1146.],
#         [1549., 1146.],
#         [1550., 1211.]]], dtype=float32), array([[[1210., 1039.],
#         [1146., 1037.],
#         [1147.,  976.],
#         [1211.,  978.]]], dtype=float32))
# Corners detected
# None
# => Processing image charucoImage9.jpg
# (array([[[ 800., 1233.],
#         [ 800., 1175.],
#         [ 861., 1177.],
#         [ 861., 1236.]]], dtype=float32), array([[[ 641., 1231.],
#         [ 641., 1171.],
#         [ 703., 1174.],
#         [ 701., 1233.]]], dtype=float32), array([[[ 391., 1063.],
#         [ 332., 1062.],
#         [ 336., 1003.],
#         [ 391., 1006.]]], dtype=float32))
# Corners detected
# None
# Corners are detected successfully!

# %%
imageSize
# Out:
# (1944, 2592)

# %%
ret, cameraMatrix, distCoefficients, rotationVecs, translationVecs, reprojectionError = calibrateCameraUsingCharuco(allCorners, allIds, imageSize)
# Out:
# STARTING CAMERA CALIBRATION
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15136/1955746078.py in <module>
# ----> 1 ret, cameraMatrix, distCoefficients, rotationVecs, translationVecs, reprojectionError = calibrateCameraUsingCharuco(allCorners, allIds, imageSize)
#
# ~\AppData\Local\Temp/ipykernel_15136/3969759848.py in calibrateCameraUsingCharuco(allCorners, allIds, imageSize)
#      11
#      12     (ret, cameraMatrix, distortionCoefficients , rotationVectors, translationVectors,
# ---> 13     stdDevIntrisics, stdDevExtrinsics, reprojectionError)  = cv2.aruco.calibrateCameraCharucoExtended(charucoCorners = allCorners,
#      14                                                                                                       charucoIds = allIds,
#      15                                                                                                       board = board,
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv_contrib\modules\aruco\src\charuco.cpp:663: error: (-215:Assertion failed) _charucoIds.total() > 0 && (_charucoIds.total() == _charucoCorners.total()) in function 'cv::aruco::calibrateCameraCharuco'

# %% [markdown]
# #### Camera Matrix:

# %%
cameraMatrix
# Out:
# array([[1.47187952e+03, 0.00000000e+00, 7.00214048e+02],
#        [0.00000000e+00, 1.47187952e+03, 3.10437811e+02],
#        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00]])

# %% [markdown]
# #### Re-projection error:
# - "ret" = the mean re-projection error
# - "reprojectionError" = vector that contains the error of all images

# %%
ret
# Out:
# 0.5679860292288063

# %%
print("RE-PROJECTION ERROR OF EACH VIEW - CHARUCO\n",reprojectionError)
# Out:
# RE-PROJECTION ERROR OF EACH VIEW - CHARUCO
#  [[0.43104837]
#  [0.71876092]
#  [0.46967368]
#  [0.67475693]
#  [0.78061067]
#  [0.47084912]
#  [0.52466702]
#  [0.4105172 ]
#  [0.48190515]
#  [0.51152328]
#  [0.55011419]
#  [0.46858363]
#  [0.68556347]
#  [0.61422282]]

# %% [markdown]
# #### Distortion Parameters

# %%
distCoefficients
# Out:
# array([[-1.01179803e+01],
#        [ 1.49230858e+02],
#        [-9.96330317e-03],
#        [ 1.24594214e-02],
#        [ 1.40580135e+02],
#        [-1.01999426e+01],
#        [ 1.49545840e+02],
#        [ 1.23627101e+02],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00],
#        [ 0.00000000e+00]])

# %% [markdown]
# ### Some tests of Aruco Module
# - Draw the detected corners in the Charuco:

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.00001)

#this image have some occlusions
testImage = cv2.imread("charucoImage1.jpg")
grayFrame = cv2.cvtColor(testImage, cv2.COLOR_BGR2GRAY)
corners, ids, rejectedImgPoints = cv2.aruco.detectMarkers(grayFrame, arucoDict)

imageWithMarkers = cv2.aruco.drawDetectedMarkers(grayFrame,corners, ids)

if len(ids) > 0 :
            
    # returns the 2D position of the chessboard corners from a ChArUco board using the detected Aruco markers
    interpolatedCorners = cv2.aruco.interpolateCornersCharuco(corners, ids, grayFrame, board)
    
    if len(interpolatedCorners[2]) > 0:
        outputImage = cv2.aruco.drawDetectedCornersCharuco(testImage, interpolatedCorners[1], interpolatedCorners[2],(0,0,255))
        
        cv2.imshow("testImage", outputImage)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15136/2125469479.py in <module>
#      13     interpolatedCorners = cv2.aruco.interpolateCornersCharuco(corners, ids, grayFrame, board)
#      14
# ---> 15     if len(interpolatedCorners[2]) > 0:
#      16         outputImage = cv2.aruco.drawDetectedCornersCharuco(testImage, interpolatedCorners[1], interpolatedCorners[2],(0,0,255))
#      17
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# - Undisort the images

# %%
image = cv2.imread("patternsImages/calibImg10.jpg")

newCameraMatrix, roi = cv2.getOptimalNewCameraMatrix(cameraMatrix, distCoefficients, imageSize, 1, imageSize)
undistortedImage = cv2.undistort(image, cameraMatrix, distCoefficients, None, newCameraMatrix)

ig, axs = plt.subplots(1,2,figsize=(7, 4), dpi=500)
axs[0].imshow(image[:,:,::-1])
axs[0].axis('off')
axs[0].set_title('distorted')
axs[1].imshow(undistortedImage[:,:,::-1])
axs[1].axis('off')
axs[1].set_title('undistorted')
# Out:
# Text(0.5, 1.0, 'undistorted')
